# %%
# %cd ../..
# Out:
# /eos/home-i00/d/driosper/bsm3g_coffea

# %%
from analysis.workflows.config import WorkflowConfigBuilder
config_builder = WorkflowConfigBuilder(workflow="2b1e")

# %%
workflow_config = config_builder.build_workflow_config()

# %%
from analysis.histograms import HistBuilder
histograms = HistBuilder(workflow_config).build_histogram()

# %%
workflow_config.event_selection[
            "categories"
        ].items()
# Out:
# dict_items([('base', ['goodvertex', 'lumi', 'trigger', 'trigger_match', 'metfilters', 'hemcleaning', 'met_50', 'exactly_two_bjets', 'tau_veto', 'muon_veto', 'exactly_one_electron'])])
